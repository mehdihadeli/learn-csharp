// %% [markdown]
// ## NuGet Packages and Dependency ManagementPackage management is really dependency management, which means compatibility, security, and reproducibility all matter when you add a package.See the full lesson in [../../docs/14-dotnet-platform-and-runtime/06-nuget-packages-and-dependency-management.md](../../docs/14-dotnet-platform-and-runtime/06-nuget-packages-and-dependency-management.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
using System.Xml.Linq;var packageReference = XElement.Parse(@"<PackageReference Include=""Humanizer"" Version=""2.14.1"" />");Console.WriteLine(packageReference.Attribute("Include")?.Value);Console.WriteLine(packageReference.Attribute("Version")?.Value);

// %% [markdown]
// Production note: package updates are engineering decisions, not only convenience actions, because dependencies affect build and runtime behavior.Return to [the full lesson](../../docs/14-dotnet-platform-and-runtime/06-nuget-packages-and-dependency-management.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### PracticeAdd a second package reference and discuss which one is a runtime dependency and which one might be build-time tooling.
