// %% [markdown]
// ## .NET Platform Overview.NET is the runtime, library, and tooling platform around C#, so understanding the platform means understanding more than language syntax.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
using System.Runtime.InteropServices;Console.WriteLine($"Framework: {RuntimeInformation.FrameworkDescription}");Console.WriteLine($"OS: {RuntimeInformation.OSDescription}");Console.WriteLine($"Architecture: {RuntimeInformation.ProcessArchitecture}");

// %% [markdown]
// Production note: platform details such as runtime version and operating system often explain behavior that source code alone does not.### PracticeCompare the current runtime information with the output of `dotnet --info` in a terminal.
