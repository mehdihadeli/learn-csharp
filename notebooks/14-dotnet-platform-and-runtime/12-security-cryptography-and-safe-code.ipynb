// %% [markdown]
// ## Security, Cryptography, and Safe CodeSecurity is a cross-cutting concern that includes inputs, secrets, dependencies, cryptography choices, and safer platform defaults.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
using System.Security.Cryptography;var bytes = RandomNumberGenerator.GetBytes(16);var token = Convert.ToBase64String(bytes);Console.WriteLine(token);Console.WriteLine($"Length: {bytes.Length} bytes");

// %% [markdown]
// Production note: secure code is usually the result of disciplined boundaries and good defaults, not one isolated security feature.### PracticeList three trust boundaries in an ordinary application and describe what should be validated at each one.
