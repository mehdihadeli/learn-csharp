// %% [markdown]
// ## Logging, Diagnostics, and ObservabilityObservability complements source code by helping you understand what a program is actually doing at runtime.See the full lesson in [../../docs/14-dotnet-platform-and-runtime/08-logging-diagnostics-and-observability.md](../../docs/14-dotnet-platform-and-runtime/08-logging-diagnostics-and-observability.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
#r "nuget: Microsoft.Extensions.Logging.Console, 9.0.0"using Microsoft.Extensions.Logging;using var loggerFactory = LoggerFactory.Create(builder => builder.AddConsole());var logger = loggerFactory.CreateLogger("NotebookDemo");logger.LogInformation("Processed {Count} records", 42);

// %% [markdown]
// Production note: logs, metrics, traces, and analyzers answer different questions, so good observability uses the right signal for the right problem.Return to [the full lesson](../../docs/14-dotnet-platform-and-runtime/08-logging-diagnostics-and-observability.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### PracticeChange the message template to log a second named value and keep it structured.
