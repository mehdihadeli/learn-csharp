// %% [markdown]
// ## Runtime, CLR, and Managed ExecutionManaged execution means the runtime participates actively in loading code, handling exceptions, tracking objects, and executing compiled instructions.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
Console.WriteLine(typeof(object).Assembly.FullName);Console.WriteLine(AppContext.BaseDirectory);Console.WriteLine(Environment.Version);

// %% [markdown]
// Production note: many language features rely on runtime behavior underneath, so troubleshooting often requires runtime awareness.### PracticeInspect another core type assembly and explain what that tells you about the execution environment.
