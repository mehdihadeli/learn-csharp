// %% [markdown]
// ## Memory Management, Garbage Collection, and ResourcesManaged memory cleanup and explicit external resource cleanup are related but not identical responsibilities.See the full lesson in [../../docs/14-dotnet-platform-and-runtime/09-memory-management-garbage-collection-and-resources.md](../../docs/14-dotnet-platform-and-runtime/09-memory-management-garbage-collection-and-resources.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
using var stream = new MemoryStream();using var writer = new StreamWriter(stream);writer.Write("managed memory and resource cleanup");writer.Flush();Console.WriteLine(stream.Length);

// %% [markdown]
// Production note: garbage collection handles unreachable managed objects, but `IDisposable` exists because files, sockets, and handles need prompt cleanup.Return to [the full lesson](../../docs/14-dotnet-platform-and-runtime/09-memory-management-garbage-collection-and-resources.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn Introduction to .NET](https://learn.microsoft.com/dotnet/core/introduction).### PracticeReplace `MemoryStream` with another disposable type and explain what external resource it represents.
