// %% [markdown]
// ## Memory Management, Garbage Collection, and ResourcesManaged memory cleanup and explicit external resource cleanup are related but not identical responsibilities.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
using var stream = new MemoryStream();using var writer = new StreamWriter(stream);writer.Write("managed memory and resource cleanup");writer.Flush();Console.WriteLine(stream.Length);

// %% [markdown]
// Production note: garbage collection handles unreachable managed objects, but `IDisposable` exists because files, sockets, and handles need prompt cleanup.### PracticeReplace `MemoryStream` with another disposable type and explain what external resource it represents.
