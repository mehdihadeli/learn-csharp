// %% [markdown]
// ## Type Conversion and ParsingParsing, conversion, and casting solve different problems, and `TryParse` is usually the safest entry point for external text input.See the full lesson in [../../docs/11-csharp-how-to-guides/02-type-conversion-and-parsing.md](../../docs/11-csharp-how-to-guides/02-type-conversion-and-parsing.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn C# how-to guides](https://learn.microsoft.com/dotnet/csharp/how-to/).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
string quantityText = "12";object value = 42;if (int.TryParse(quantityText, out var quantity)){    Console.WriteLine($"Parsed quantity: {quantity}");}if (value is int count){    Console.WriteLine($"Pattern-matched count: {count}");}

// %% [markdown]
// Production note: use exceptions for exceptional failures, not for ordinary user input that may legitimately be invalid.Return to [the full lesson](../../docs/11-csharp-how-to-guides/02-type-conversion-and-parsing.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn C# how-to guides](https://learn.microsoft.com/dotnet/csharp/how-to/).### PracticeTry the same example with an invalid number string and keep the program on the non-throwing path.
