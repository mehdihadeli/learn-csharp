# %% [markdown]
# ## LINQ Basics
#
# LINQ gives C# a uniform query vocabulary over collections and queryable sources. It changes how you think about data manipulation by encouraging composition over manual loops.
# See the full lesson in [../../docs/08-practical-csharp/01-linq-basics.md](../../docs/08-practical-csharp/01-linq-basics.md) for the broader explanation and surrounding context.
# Original Microsoft Learn reference: [Microsoft Learn C# guide](https://learn.microsoft.com/dotnet/csharp/).
#
# ### Real-world angle
#
# Practical topics connect language features to actual programs. They are where syntax starts interacting with files, tasks, libraries, diagnostics, and operational concerns.
#
# - Tie the concept to real application behavior.
# - Include failure and maintenance considerations.
# - Connect syntax to the relevant library APIs.
#
# ### Example

# %%
var numbers = new[] { 1, 2, 3, 4, 5 };
var evens = numbers.Where(n => n % 2 == 0);
Console.WriteLine(string.Join(", ", evens));
# Out:
# 2, 4

# %% [markdown]
# Treat the example as a seed for a realistic task. Add validation, error handling, or a surrounding API call so the concept connects to actual application behavior.
#
# ### Production note
#
# Real-world code must handle environment, failures, and maintenance, not just the happy path.
#
# Official Microsoft Learn reference: [Microsoft Learn C# guide](https://learn.microsoft.com/dotnet/csharp/).### Practice
#
# Combine this topic with one nearby .NET API so it feels like application code instead of isolated syntax.
#
# Return to [the full lesson](../../docs/08-practical-csharp/01-linq-basics.md) when you want the fuller explanation, tradeoffs, and surrounding examples.
