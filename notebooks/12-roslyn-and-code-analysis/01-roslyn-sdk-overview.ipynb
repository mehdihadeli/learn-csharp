// %% [markdown]
// ## Roslyn SDK OverviewRoslyn exposes the compiler model so tools can inspect syntax, resolve semantics, and build refactorings, analyzers, or generators.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
#r "nuget: Microsoft.CodeAnalysis.CSharp, 4.13.0"using Microsoft.CodeAnalysis.CSharp;var tree = CSharpSyntaxTree.ParseText("int total = 1 + 2;");Console.WriteLine(tree.GetRoot().Kind());

// %% [markdown]
// Production note: Roslyn becomes easier when you start from the tooling question you want to answer instead of memorizing API names in isolation.### PracticeParse a second snippet and inspect a different root node kind.
