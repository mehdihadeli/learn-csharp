// %% [markdown]
// ## What's New in C# 12C# 12 reduced common boilerplate, especially around collection creation and construction patterns that appear frequently in everyday code.### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
int[] values = [1, 2, 3, 4];List<string> names = ["Ada", "Lina", "Sara"];int[] combined = [.. values, 5, 6];Console.WriteLine(string.Join(", ", names));Console.WriteLine(string.Join(", ", combined));

// %% [markdown]
// Production note: use newer syntax where it improves clarity, not simply because it is newer.### PracticeRewrite one older array or list initialization using collection expressions and compare readability.
