// %% [markdown]
// ## What's New in C# 12C# 12 reduced common boilerplate, especially around collection creation and construction patterns that appear frequently in everyday code.See the full lesson in [../../docs/13-whats-new-in-csharp/02-whats-new-in-csharp-12.md](../../docs/13-whats-new-in-csharp/02-whats-new-in-csharp-12.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn What's new in C#](https://learn.microsoft.com/dotnet/csharp/whats-new/).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
int[] values = [1, 2, 3, 4];List<string> names = ["Ada", "Lina", "Sara"];int[] combined = [.. values, 5, 6];Console.WriteLine(string.Join(", ", names));Console.WriteLine(string.Join(", ", combined));

// %% [markdown]
// Production note: use newer syntax where it improves clarity, not simply because it is newer.Return to [the full lesson](../../docs/13-whats-new-in-csharp/02-whats-new-in-csharp-12.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn What's new in C#](https://learn.microsoft.com/dotnet/csharp/whats-new/).### PracticeRewrite one older array or list initialization using collection expressions and compare readability.
