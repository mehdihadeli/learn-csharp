// %% [markdown]
// ## What's New in C# 14 and C# 15The newest versions need the most cautious teaching posture because stable and preview features should not be presented with the same confidence level.See the full lesson in [../../docs/13-whats-new-in-csharp/04-whats-new-in-csharp-14-and-15.md](../../docs/13-whats-new-in-csharp/04-whats-new-in-csharp-14-and-15.md) for the broader explanation and surrounding context.Original Microsoft Learn reference: [Microsoft Learn What's new in C#](https://learn.microsoft.com/dotnet/csharp/whats-new/).### Real-world angleUse this notebook to run a focused example, observe the output, and connect the concept to ordinary .NET development work.### Example

// %%
var features = new[]{    new { Name = "null-conditional assignment", Status = "stable" },    new { Name = "field keyword for field-backed properties", Status = "stable" },    new { Name = "future preview feature", Status = "preview" }};foreach (var feature in features.Where(item => item.Status == "stable")){    Console.WriteLine($"Adopt first: {feature.Name}");}

// %% [markdown]
// Production note: separate stable adoption guidance from preview exploration so readers do not confuse the two.Return to [the full lesson](../../docs/13-whats-new-in-csharp/04-whats-new-in-csharp-14-and-15.md) when you want the fuller explanation, tradeoffs, and surrounding examples.Official Microsoft Learn reference: [Microsoft Learn What's new in C#](https://learn.microsoft.com/dotnet/csharp/whats-new/).### PracticeAdd a second preview item and describe how you would document it differently from a released feature.
